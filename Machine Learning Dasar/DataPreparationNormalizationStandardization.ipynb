# %%
#import library minmaxscaler
from sklearn.preprocessing import MinMaxScaler

#input data
data = [[12000000, 33], [35000000, 45], [4000000, 23], [6500000, 26], [9000000, 29]]

scaler = MinMaxScaler()

#menghitung nilai minimum dan maksimum
scaler.fit(data)

#mengaplikasikan scaler pada data
print(scaler.transform(data))
# Out:
# [[0.25806452 0.45454545]
#  [1.         1.        ]
#  [0.         0.        ]
#  [0.08064516 0.13636364]
#  [0.16129032 0.27272727]]

# %%
#import library preprocessing
from sklearn import preprocessing

#membuat data dummy
data = [[12000000, 33], [35000000, 45], [4000000, 23], [6500000, 26], [9000000, 29]]

#menghitung rata-rata dan deviasi standar
scaler=preprocessing.StandardScaler().fit(data)

#mengimplementasikan standard saler pada data
data = scaler.transform(data)
data
# Out:
# array([[-0.11638732,  0.23521877],
#        [ 1.94277296,  1.80334389],
#        [-0.83261698, -1.07155217],
#        [-0.60879521, -0.67952089],
#        [-0.38497344, -0.28748961]])
